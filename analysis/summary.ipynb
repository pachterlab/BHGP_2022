    "GSM4037988",
    "SRX4733402",
    "ERS3861800",
    "ERS4228637",
    "GSM2905292",
    "GSM3360834",
    "GSM3439926",
    "GSM3576408",
    "GSM3711776",
    "GSM3755692",
    "GSM4037989",
    "SRX4733403",
    "ERS3861801",
    "ERS4228638",
    "GSM2905293",
    "GSM3360835",
    "GSM3439927",
    "GSM3576409",
    "GSM3711777",
    "GSM3755693",
    "GSM4037990",
    "SRX4733411",
    "ERS3861802",
    "ERS4228639",
    "GSM2928377",
    "GSM3360836",
    "GSM3439987",
    "GSM3576410",
    "GSM3711778",
    "GSM3755696",
    "GSM4037991",
    "svensson_2017_1",
    "ERS3861803",
    "ERS4228662",
    "GSM2928378",
    "GSM3360837",
    "GSM3439988",
    "GSM3576411",
    "GSM3711779",
    "GSM3755697",
    "GSM4037992",
    "svensson_2017_2",
    "ERS3861804",
    "ERS4228663",
    "GSM2928379",
    "GSM3360838",
    "GSM3439989",
    "GSM3576412",
    "GSM3711780",
    "GSM3755698",
    "GSM4037993",
    "zheng_2017",
    "ERS3861805",
    "ERS4228664",
    "GSM2928380",
    "GSM3375767",
    "GSM3509837",
    "GSM3576413",
]

# %%
import json
import os
import sys
from collections import OrderedDict
from glob import glob

import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
from matplotlib.gridspec import GridSpec
from scipy import stats
from scipy.io import mmread, mmwrite
from scipy.sparse import csr_matrix
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import normalize, scale


def nd(arr):
    return np.asarray(arr).reshape(-1)


def yex(ax):
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]

    # now plot both limits against eachother
    ax.plot(lims, lims, "k-", alpha=0.75, zorder=0)
    ax.set_aspect("equal")
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax


def setup_colorbar(ax):
    from mpl_toolkits.axes_grid1 import make_axes_locatable

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    return cax


import warnings

warnings.filterwarnings("ignore")

fsize = 15
alpha = 0.33

base_figure_path = "figures"

import matplotlib

matplotlib.rcParams["mathtext.fontset"] = "cm"
matplotlib.rcParams["font.family"] = "STIXGeneral"
matplotlib.rcParams["font.size"] = fsize
# %config InlineBackend.figure_format = 'retina'

# %%
cividis = matplotlib.cm.get_cmap("cividis")
colors = {"cell": cividis(0.01), "gene": cividis(0.5), "mono": cividis(0.99)}

# %%
def makeDF(fns, met_labels):
    metrics = []
    for fn in fns:
        acc = fn.split("/")[2]
        with open(fn, "r") as f:
            m = json.load(f)
            d = {k: m.pop(k, None) for k in met_labels}

            df = pd.DataFrame(m).T.reset_index()
            df["ds"] = acc
            for ml in met_labels:
                df[ml] = d[ml]
            metrics.append(df)
    df = pd.concat(metrics)
    return df

# %%
fns = [os.path.join("synchromesh/data/", i, f"subset_genes/{i}_subset_genes_metrics.json") for i in observations]

met_labels = [
    "ncells",
    "ngenes",
    "density",
    "total_counts",
    "avg_per_cell",
    "avg_per_gene",
    "min_cell",
    "max_cell",
    "nvals",
    "overdispersion",
]

labels = [
    "raw",
    "PF",
    "sqrt",
    "log1p",
    "log1pCP10k",
    "log1pCPM",
    "scalelog1pCP10k",
    "sctransform",
    "log1pPF",
    "PFlog1pPF",
]

nan = np.array(['ERS4228665',
 'GSM3576415',
 'GSM3576416',
 'GSM3576418',
 'CRX102286',
 'CRX102292',
 'GSM3576425',
 'GSM3731527',
 'GSM3396166',
 'GSM3148578',
 'GSM3576429',
 'CRX118014',
 'ERX2756731',
 'GSM3576398',
 'GSM4037323',
 'GSM3576410'])

df = makeDF(fns, met_labels)

# # drop nans
# df = df[~df["ds"].isin(nan)]

# # compute 1-spearman
# df["r_mono"] = 1 - np.abs(df["r_mono"])

# # compute delta max min cell
# df["delta_cell"] = df["max_cell"] - df["min_cell"]

# mall = df.copy()
# # filter by avg_per_cell
# min_avg_per_cell = (
#     mall.query("index == 'raw'")
#     .query("ds == 'angelidis_2019'")["avg_per_cell"]
#     .values[0]
# )
# passing_ds = np.unique(mall.query(f"avg_per_cell >= {min_avg_per_cell}")["ds"])

# mall.query("index == 'raw'").query("ds == 'angelidis_2019'")

# %%
df["overdispersion"].isna().sum()
# Out:
# 10

# %%
min_avg_per_cell
# Out:
# 818.4679673259974

# %%
print(f"{len(observations):,.0f} total observations")
print(f"{mall['ds'].nunique():,.0f} non-nan observations")
print(f"{nan.shape[0]:,.0f}  nan observations")
print(f"{passing_ds.shape[0]:,.0f} pass filter")

print("")
print(f"{mall['ds'].nunique() * mall['index'].nunique():,.0f} Expected entries")
print(f"{mall.shape[0]:,.0f} Observed entries")
# Out:
# 526 total observations
# 510 non-nan observations
# 16  nan observations
# 437 pass filter
#
# 5,100 Expected entries
# 5,100 Observed entries

# %% [markdown]
# # All methods

# %%
metrics = mall[mall["ds"].isin(passing_ds)]

fig, axs = plt.subplots(figsize=(10, 5 * 3), nrows=3)
fig.subplots_adjust(hspace=0)
fig.suptitle(
    f"{metrics['ds'].nunique():,.0f} of {len(observations):,.0f} pass-filter observations on sctransform-gene subset",
    y=0.9,
)

ds_name = "10xv3_nih_3t3"
ds_idx = np.flatnonzero(metrics.query("index == 'raw'").eval(f"ds == '{ds_name}'"))[0]
unique_size = 9 ** 2

gb = metrics.groupby("index")

for ax, met, color, ylabel in zip(
    axs,
    ["cov_gene", "r2_depth", "r_mono"],
    ["gene", "cell", "mono"],
    [
        "Coefficient of variation gene variance",
        "Pearson $r^2$ cell depth",
        "1 - $|$mean Spearman r cell transform$|$",
    ],
):

    # get ndarray
    v = gb[met].apply(np.array).loc[labels]
    x = v.index.values
    y = np.concatenate(v.values).reshape(v.values.shape[0], -1)[:, ::-1]

    # jitter the points
    j = np.random.normal(0, 0.125, size=y.shape)
    # get constant matrix to plot scatter
    _, Y = np.meshgrid(np.arange(y.shape[1]), np.arange(y.shape[0]))

#     # means as bars
#     ax.bar(x, y.mean(1), facecolor=colors[color], edgecolor="k")

    # all points
#     ax.scatter(Y + j, y, facecolor=colors[color], s=15)
    ax.boxplot(y.T, positions=np.arange(len(labels)), 
               patch_artist=True, notch=True,
               boxprops=dict(facecolor=colors[color]), 
               medianprops=dict(color=colors[color]),
               flierprops=dict(markerfacecolor=colors[color], markeredgecolor='k')
              )
    
    # means line
    mean_line = ax.scatter(
        np.arange(x.shape[0]),
        y.mean(1),
        color="k",
        label="mean",
        s=unique_size*17,
        linewidth=3,
        marker="_",
        zorder=10
    )
    
    # means dot
    mean_dot = ax.scatter(
        np.arange(x.shape[0]),
        y.mean(1),
        facecolor="white",
        edgecolor="k",
        label="mean",
        s=unique_size,
        zorder=10
    )


    # dataset specific
    ds_dot = ax.scatter(
        Y[:, ds_idx],
        y[:, ds_idx],
        facecolor="#DC3220",
        edgecolor="k",
        s=unique_size,
        label=ds_name,
        zorder=10
    )

    ax.set(
        **{
            "ylabel": ylabel,
        }
    )
    if met == "cov_gene":
        ax.set_ylim(0, 250)
    elif met == "r_mono":
        ax.set_ylim(0, 1.1)

    ax.legend([(mean_line, mean_dot), ds_dot], ["mean", ds_name])

ax.set_xticklabels(x, ha="right", rotation=45)

base_file_name = "metrics_subset_genes"
save_path = os.path.join(base_figure_path, base_file_name)
if not os.path.exists(save_path):
    os.makedirs(save_path)

fig.savefig(
    os.path.join(save_path, f"{base_file_name}.png"),
    facecolor="white",
    transparent=False,
    dpi=300,
    bbox_inches="tight",
)
fig.savefig(
    os.path.join(save_path, f"{base_file_name}.pdf"), dpi=300, bbox_inches="tight"
)

fig.show()

# %%
# find pairs of datasets that which order between two methods (which ones? sqrt, log1p)

# %%
s = metrics.query("index == 'sqrt'")[["cov_gene", "ds"]]
l = metrics.query("index == 'log1p'")[["cov_gene", "ds"]]

# %%
arrs = (s['cov_gene'].values[:, None] - s['cov_gene'].values)
arrl = (l['cov_gene'].values[:, None] - l['cov_gene'].values)
# arr[arr > 0] = 1
# arr[arr < 0] = -1

barrs = arrs.copy()
barrs[barrs > 0] = 1
barrs[barrs < 0] = 0

barrl = arrl.copy()
barrl[barrl > 0] = 1
barrl[barrl < 0] = 0

# %%
v = np.stack([arrs, arrl], axis=2) # arrs, arrs stacked
b = np.stack([barrs, barrl], axis=2).astype(bool) # barrs, barrs stacked

# %%
D = np.abs(v[:,:,0] - v[:,:,1]) 
D[b.sum(2)!= 1] = 0

# %%
n = 6 # make it even since matrix is symmmetric
ind = np.argpartition(D.ravel(), -n)[-n:]

# %%
maxidx = [( i // D.shape[1], i % D.shape[1]) for i in ind]
maxidx
# Out:
# [(82, 141), (141, 82), (82, 345), (345, 82), (189, 141), (141, 189)]

# %%
# drop every second pair (just the transpose)
maxidx = [( i // D.shape[1], i % D.shape[1]) for i in ind[::2]]
maxidx
# Out:
# [(82, 141), (82, 345), (189, 141)]

# %%
# amax = D.argmax()
# cidx = amax % D.shape[1]
# ridx = amax // D.shape[1]

# %%
[D[i] for i in maxidx]
# Out:
# [36.61405082516698, 36.804503044492975, 37.09362022743225]

# %%
maxidx
# Out:
# [(82, 141), (82, 345), (189, 141)]

# %%
[print(s.iloc[[*idx]], '\n') for idx in maxidx]
# Out:
#     cov_gene          ds
# 2  45.142761  GSM3396163
# 2   9.455554  GSM3178783
#
#     cov_gene          ds
# 2  45.142761  GSM3396163
# 2   8.431308  GSM2877959
#
#     cov_gene          ds
# 2  46.527815  GSM3396177
# 2   9.455554  GSM3178783
# [None, None, None]

# %%
[print(l.iloc[[*idx]], '\n') for idx in maxidx]
# Out:
#    cov_gene          ds
# 3   4.86924  GSM3396163
# 3  5.796083  GSM3178783
#
#    cov_gene          ds
# 3   4.86924  GSM3396163
# 3  4.962289  GSM2877959
#
#    cov_gene          ds
# 3  5.774724  GSM3396177
# 3  5.796083  GSM3178783
# [None, None, None]

# %%
for ridx, cidx in maxidx:
    print(f"SQRT  : {s.iloc[ridx]['ds']} - {s.iloc[cidx]['ds']} = ", s.iloc[ridx]["cov_gene"] - s.iloc[cidx]["cov_gene"])
    print(f"LOG1P : {l.iloc[ridx]['ds']} - {l.iloc[cidx]['ds']} = ", l.iloc[ridx]["cov_gene"] - l.iloc[cidx]["cov_gene"])
    print("\n")
# Out:
# SQRT  : GSM3396163 - GSM3178783 =  35.68720743966064
# LOG1P : GSM3396163 - GSM3178783 =  -0.9268433855063405
#
#
# SQRT  : GSM3396163 - GSM2877959 =  36.711453701108496
# LOG1P : GSM3396163 - GSM2877959 =  -0.09304934338448234
#
#
# SQRT  : GSM3396177 - GSM3178783 =  37.07226071459
# LOG1P : GSM3396177 - GSM3178783 =  -0.021359512842244577

# %%
metrics.query("ds == 'angelidis_2019'")
# Out:
#              index   cov_gene  r2_depth    r_mono  cov_cell              ds  \
# 0              raw  98.799437       1.0       0.0   0.99077  angelidis_2019
# 1               PF  72.846262       0.0       0.0       0.0  angelidis_2019
# 2             sqrt  12.494603  0.811931       0.0  0.716678  angelidis_2019
# 3            log1p   3.411364  0.796664       0.0  0.727665  angelidis_2019
# 4       log1pCP10k   1.915849  0.435042       0.0  0.363246  angelidis_2019
# 5         log1pCPM   1.677016  0.672056       0.0  0.523227  angelidis_2019
# 6  scalelog1pCP10k        0.0  0.422731  0.734228       NaN  angelidis_2019
# 7      sctransform     3.6556  0.350063  0.770767       NaN  angelidis_2019
# 8          log1pPF   3.044478  0.057111       0.0  0.216499  angelidis_2019
# 9        PFlog1pPF   3.966494       0.0       0.0       0.0  angelidis_2019
#
#    ncells  ngenes   density  total_counts  avg_per_cell  avg_per_gene  \
# ...

# %%
metrics["cov_gene"] = metrics["cov_gene"].astype(float).values

# %%
# log1p hihg sqrt low
metrics.query("index == 'sqrt'").nsmallest(10, columns=["cov_gene"])
# Out:
#   index  cov_gene  r2_depth r_mono  cov_cell            ds  ncells  ngenes  \
# 2  sqrt  0.635617  0.987171    0.0  0.152338    klein_2015     953   25025
# 2  sqrt  1.604510  0.883297    0.0  0.163767    GSM3738540     904   18304
# 2  sqrt  1.884272  0.985528    0.0  0.152628  macosko_2015      84      69
# 2  sqrt  1.888113  0.976179    0.0  0.581078    GSM3319047     137    3378
# 2  sqrt  1.915377  0.949515    0.0  0.199022    GSM2928377    2893   33451
# 2  sqrt  1.969158  0.904393    0.0  0.238456    GSM3738536     827   18344
# 2  sqrt  2.030603  0.904995    0.0  0.223473    ERS3861827    1914   23664
# 2  sqrt  2.038948  0.971934    0.0   0.23159    ERX2756711     700   11124
# 2  sqrt  2.046367  0.976537    0.0  0.329045    GSM3509838    2614   26511
# 2  sqrt  2.161007  0.963795    0.0  0.285495    GSM2928378    3462   33333
#
#     density  total_counts  avg_per_cell  avg_per_gene  min_cell  max_cell  \
# ...

# %%
metrics.query("index == 'log1p'").nlargest(10, columns=["cov_gene"])
# Out:
#    index  cov_gene  r2_depth r_mono  cov_cell          ds  ncells  ngenes  \
# 3  log1p  7.447288  0.566683    0.0  1.696487  ERS3861813    5218   12458
# 3  log1p  6.777033  0.270518    0.0  0.989003  GSM3396184    7926   12427
# 3  log1p  6.160147  0.638828    0.0  1.693198  GSM3396178   12668   20161
# 3  log1p  5.796083  0.877275    0.0  0.737893  GSM3178783   71720   23787
# 3  log1p  5.774724  0.365127    0.0  0.971108  GSM3396177    1870    9594
# 3  log1p  5.574181  0.639241    0.0   2.14813  GSM3178782   15841   20925
# 3  log1p  5.441116  0.969653    0.0  1.395289  GSM3732364    9548   24003
# 3  log1p  5.330959  0.516164    0.0   1.11438  GSM3396165    9412   24827
# 3  log1p  5.254411  0.927118    0.0  1.129005  GSM4037301    5535   23575
# 3  log1p  5.012249  0.648029    0.0  1.329012  GSM3396173    9198   23140
#
#     density  total_counts  avg_per_cell  avg_per_gene  min_cell  max_cell  \
# 3  0.014032       6290848   1205.610000    504.960000        13     14816
# ...

# %%
gb["cov_gene"].max().sort_values()
# Out:
# index
# scalelog1pCP10k    1.429585e-12
# log1pCPM           4.243860e+00
# log1pCP10k         6.491764e+00
# log1pPF            7.246424e+00
# log1p              7.447288e+00
# sctransform        7.855891e+00
# sqrt               4.715665e+01
# PFlog1pPF          8.238062e+01
# PF                 1.364434e+02
# raw                1.403395e+02
# Name: cov_gene, dtype: float64

# %%
gb["cov_gene"].mean().sort_values()
# Out:
# index
# scalelog1pCP10k    7.991440e-14
# sctransform        9.175664e-01
# log1pCPM           1.509013e+00
# log1pCP10k         2.313139e+00
# log1pPF            2.783445e+00
# log1p              2.845216e+00
# sqrt               8.298185e+00
# PFlog1pPF          9.634912e+00
# PF                 6.312949e+01
# raw                6.345046e+01
# Name: cov_gene, dtype: float64

# %%
metrics.query("index == 'sctransform'").sort_values("r2_depth")
# Out:
#           index  cov_gene  r2_depth    r_mono cov_cell          ds  ncells  \
# 7   sctransform  0.552327  0.000074  0.773171      NaN  GSM4475052    2098
# 7   sctransform  1.939676  0.000079  0.843489      NaN  GSM3178786    8609
# 7   sctransform  1.771355  0.000388  0.632263      NaN  GSM3396171     869
# 7   sctransform  1.196620  0.000606  0.736036      NaN  GSM3755691    7998
# 7   sctransform  0.479143  0.000666  0.756648      NaN  GSM4339769    3750
# ..          ...       ...       ...       ...      ...         ...     ...
# 7   sctransform  0.804150  0.857295  0.850405      NaN  GSM3439989    6471
# 7   sctransform  0.803355  0.864569  0.852436      NaN  GSM4080089    6471
# 7   sctransform  0.656098  0.904321  0.840243      NaN  GSM3735993    9240
# 7   sctransform  0.604124  0.924077  0.826378      NaN  GSM3738543    3719
# 7   sctransform  0.508184  0.952869  0.932466      NaN  klein_2015     953
#
# ...

# %%
gb["r2_depth"].max().sort_values()
# Out:
# index
# PF                 0.000000
# PFlog1pPF          0.000000
# log1pPF            0.911441
# log1pCP10k         0.936777
# scalelog1pCP10k    0.937171
# sctransform        0.952869
# log1pCPM           0.970805
# sqrt               0.991482
# log1p              0.991874
# raw                1.000000
# Name: r2_depth, dtype: float64

# %%
gb["r2_depth"].mean().sort_values()
# Out:
# index
# PF                 0.000000
# PFlog1pPF          0.000000
# sctransform        0.373463
# log1pPF            0.431846
# scalelog1pCP10k    0.484079
# log1pCP10k         0.510436
# log1pCPM           0.758788
# log1p              0.893449
# sqrt               0.905079
# raw                1.000000
# Name: r2_depth, dtype: float64

# %%
gb["r_mono"].mean().sort_values()
# Out:
# index
# PF                 0.000000
# PFlog1pPF          0.000000
# log1p              0.000000
# log1pCP10k         0.000000
# log1pCPM           0.000000
# log1pPF            0.000000
# raw                0.000000
# sqrt               0.000000
# scalelog1pCP10k    0.643350
# sctransform        0.760519
# Name: r_mono, dtype: float64

# %% [markdown]
# # Sparse

# %%
fns = [
    os.path.join("synchromesh/data/", i, f"all_genes/{i}_all_genes_metrics.json") for i in observations
]

met_labels = [
    "ncells",
    "ngenes",
    "density",
    "total_counts",
    "avg_per_cell",
    "avg_per_gene",
    "min_cell",
    "max_cell",
    "nvals",
    "overdispersion",
]

labels = [
    "raw",
    "PF",
    "sqrt",
    "log1p",
    "log1pCP10k",
    "log1pCPM",
    "log1pPF",
    "PFlog1pPF",
]

df = makeDF(fns, met_labels)

# drop nans
df = df[~df["ds"].isin(nan)]

# compute 1-spearman
df["r_mono"] = 1 - np.abs(df["r_mono"])

# compute delta max min cell
df["delta_cell"] = df["max_cell"] - df["min_cell"]

msp = df.copy()

# %%
print(f"{len(observations):,.0f} total observations")
print(f"{msp['ds'].nunique():,.0f} non-nan observations")
print(f"{nan.shape[0]:,.0f}  nan observations")
print(f"{passing_ds.shape[0]:,.0f} pass filter")

print("")
print(f"{msp['ds'].nunique() * msp['index'].nunique():,.0f} Expected entries")
print(f"{msp.shape[0]:,.0f} Observed entries")
# Out:
# 526 total observations
# 510 non-nan observations
# 16  nan observations
# 437 pass filter
#
# 4,080 Expected entries
# 4,080 Observed entries

# %% [markdown]
# # All methods

# %%
metrics = msp[msp.ds.isin(passing_ds)]

fig, axs = plt.subplots(figsize=(10, 5 * 3), nrows=3)
fig.subplots_adjust(hspace=0)
fig.suptitle(
    f"{metrics['ds'].nunique():,.0f} of {len(observations):,.0f} pass-filter observations on sctransform-gene subset",
    y=0.9,
)

ds_name = "10xv3_nih_3t3"
ds_idx = np.flatnonzero(metrics.query("index == 'raw'").eval(f"ds == '{ds_name}'"))[0]
unique_size = 9 ** 2

gb = metrics.groupby("index")

for ax, met, color, ylabel in zip(
    axs,
    ["cov_gene", "r2_depth", "r_mono"],
    ["gene", "cell", "mono"],
    [
        "Coefficient of variation gene variance",
        "Pearson $r^2$ cell depth",
        "1 - $|$mean Spearman r cell transform$|$",
    ],
):

    # get ndarray
    v = gb[met].apply(np.array).loc[labels]
    x = v.index.values
    y = np.concatenate(v.values).reshape(v.values.shape[0], -1)[:, ::-1]

    # jitter the points
    j = np.random.normal(0, 0.125, size=y.shape)
    # get constant matrix to plot scatter
    _, Y = np.meshgrid(np.arange(y.shape[1]), np.arange(y.shape[0]))

#     # means as bars
#     ax.bar(x, y.mean(1), facecolor=colors[color], edgecolor="k")

    # all points
#     ax.scatter(Y + j, y, facecolor=colors[color], s=15)
    ax.boxplot(y.T, positions=np.arange(len(labels)), 
               patch_artist=True, notch=True,
               boxprops=dict(facecolor=colors[color]), 
               medianprops=dict(color=colors[color]),
               flierprops=dict(markerfacecolor=colors[color], markeredgecolor='k')
              )
    
    # means line
    mean_line = ax.scatter(
        np.arange(x.shape[0]),
        y.mean(1),
        color="k",
        label="mean",
        s=unique_size*17,
        linewidth=3,
        marker="_",
        zorder=10
    )
    
    # means dot
    mean_dot = ax.scatter(
        np.arange(x.shape[0]),
        y.mean(1),
        facecolor="white",
        edgecolor="k",
        label="mean",
        s=unique_size,
        zorder=10
    )


    # dataset specific
    ds_dot = ax.scatter(
        Y[:, ds_idx],
        y[:, ds_idx],
        facecolor="#DC3220",
        edgecolor="k",
        s=unique_size,
        label=ds_name,
        zorder=10
    )

    ax.set(
        **{
            "ylabel": ylabel,
        }
    )
    if met == "cov_gene":
        ax.set_ylim(0, 250)
    elif met == "r_mono":
        ax.set_ylim(0, 1.1)

    ax.legend([(mean_line, mean_dot), ds_dot], ["mean", ds_name])

ax.set_xticklabels(x, ha="right", rotation=45)

base_file_name = "metrics_all_genes"
save_path = os.path.join(base_figure_path, base_file_name)
if not os.path.exists(save_path):
    os.makedirs(save_path)

fig.savefig(
    os.path.join(save_path, f"{base_file_name}.png"),
    facecolor="white",
    transparent=False,
    dpi=300,
    bbox_inches="tight",
)
fig.savefig(
    os.path.join(save_path, f"{base_file_name}.pdf"), dpi=300, bbox_inches="tight"
)

fig.show()

# %%
gb["cov_gene"].mean().sort_values()
# Out:
# index
# log1pCPM        2.811296
# log1pCP10k      4.037834
# log1pPF         4.827328
# log1p           4.899809
# sqrt           13.975419
# PFlog1pPF      16.560516
# PF            105.009173
# raw           105.306907
# Name: cov_gene, dtype: float64

# %%
gb["r2_depth"].mean().sort_values()
# Out:
# index
# PF            0.000000
# PFlog1pPF     0.000000
# log1pPF       0.433022
# log1pCP10k    0.511473
# log1pCPM      0.761663
# log1p         0.894851
# sqrt          0.906152
# raw           1.000000
# Name: r2_depth, dtype: float64

# %%
gb["r_mono"].mean().sort_values()
# Out:
# index
# PF            0.0
# PFlog1pPF     0.0
# log1p         0.0
# log1pCP10k    0.0
# log1pCPM      0.0
# log1pPF       0.0
# raw           0.0
# sqrt          0.0
# Name: r_mono, dtype: float64

# %% [markdown]
# -----

# %%
# # Example using colorbar

# fig, ax = plt.subplots(figsize=(6,6))

# tmp = msp.query("index == 'raw'")
# x = tmp["avg_per_cell"].values
# argsort = np.argsort(x)

# x = x[argsort][::-1]
# y = np.arange(x.shape[0])
# c = tmp["cov_gene"].values[argsort][::-1]

# im = ax.scatter(x,y, c=c, s=100, cmap="Reds")

# ax.set(**{
#     "xlabel": "Avg. per cell",
#     "ylabel": "Observation rank",
#     "xscale": "log",
#     "yscale": "log"
# })
# # ax.legend()

# cax = setup_colorbar(ax)
# fig.colorbar(im, cax=cax, label="CoV gene variances")

# fig.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))

tmp = msp.query("index == 'raw'")
x = tmp["avg_per_cell"].values
argsort = np.argsort(x)

x = x[argsort][::-1]
y = np.arange(x.shape[0])

im = ax.scatter(x, y, s=100, edgecolor="k", facecolor="white")

lcolor = "lightgray"

meanx = x.mean()
ny = (x > meanx).sum()
ax.axvline(meanx, color=lcolor, linestyle="--", label=f"mean: {meanx:,.0f}")
ax.axhline(ny, color=lcolor, linestyle="--")
ax.annotate(
    f"mean: ({meanx:,.0f}, {ny:,.0f})",
    xy=(meanx, ny),
    xycoords="data",
    xytext=(5, 5),
    textcoords="offset points",
)


ny = (x > min_avg_per_cell).sum()
ax.axvline(
    min_avg_per_cell,
    color=lcolor,
    linestyle="--",
    label=f"Angelidis 2019: {min_avg_per_cell:,.0f}",
)
ax.axhline(ny, color=lcolor, linestyle="--")
ax.annotate(
    f"Angelidis 2019 cutoff: ({min_avg_per_cell:,.0f}, {ny:,.0f})",
    xy=(min_avg_per_cell, ny),
    xycoords="data",
    xytext=(5, 5),
    textcoords="offset points",
)

ax.set(
    **{
        "xlabel": "Avg. per cell",
        "ylabel": "Observation rank",
        "xscale": "log",
        "yscale": "log",
    }
)

fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 5))

tmp = msp.query("index == 'raw'")
x = np.sort(tmp["density"].values * 100)[::-1]
y = np.arange(x.shape[0])

meanx = x.mean()
ny = (x > meanx).sum()

ax.scatter(x, y, edgecolor="k", facecolor="white")
ax.axvline(meanx, color="k", linestyle="--", label=f"mean: {meanx:,.2f}%")


ax.axhline(ny, color="k", linestyle="--")

ax.annotate(
    f"({meanx:,.1f}%, {ny:,.0f})",
    xy=(meanx, ny),
    xycoords="data",
    xytext=(10, 10),
    textcoords="offset points",
)
ax.set(
    **{
        "xlabel": "Density (% nonzeros)",
        "ylabel": "Dataset rank",
        "xscale": "log",
        "yscale": "log",
    }
)
ax.legend()
fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 5))

tmp = msp.query("index == 'raw'")
x = np.sort(tmp["overdispersion"].values)[::-1]
y = np.arange(x.shape[0])

meanx = x.mean()
ny = (x > meanx).sum()

ax.scatter(x, y, edgecolor="k", facecolor="white")
ax.axvline(meanx, color="k", linestyle="--", label=f"mean: {meanx:,.2f}%")
ax.axhline(ny, color="k", linestyle="--")
ax.annotate(
    f"mean: ({meanx:,.1f}, {ny:,.0f})",
    xy=(meanx, ny),
    xycoords="data",
    xytext=(10, 10),
    textcoords="offset points",
)

ax.set(
    **{
        "xlabel": "Overdispersion",
        "ylabel": "Dataset rank",
        "xscale": "log",
        "yscale": "log",
    }
)
ax.legend()
fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 5))

tmp = msp[msp["ds"].isin(passing_ds)].query("index == 'raw'")
x = np.sort(tmp["overdispersion"].values)[::-1]

logx = np.log(x)
meanx = np.mean(logx)
ax.hist(logx, edgecolor="k")
ax.axvline(meanx, color="k", linestyle="--", label=f"mean: {meanx:,.2f}")
ax.set(
    **{
        "xlabel": "log(Overdispersion)",
        "ylabel": "Frequency",
    }
)
ax.legend()
fig.show()

# %%
np.exp(meanx)
# Out:
# 1.4667550682259465

# %%
fig, ax = plt.subplots(figsize=(5, 5))

tmp = msp[msp["ds"].isin(passing_ds)].query("index == 'raw'")

x = tmp["avg_per_cell"]

logx = np.log(x)
meanx = np.mean(logx)
ax.hist(logx, edgecolor="k", density=True, bins=35)
ax.axvline(meanx, color="k", linestyle="--", label=f"mean: {meanx:,.2f}")
ax.set(
    **{
        "xlabel": "log(Avg. cell depth)",
        "ylabel": "Frequency",
    }
)
ax.legend()
fig.show()

# %%
np.exp(meanx)
# Out:
# 14717705.862512792

# %%
labels
# Out:
# ['raw',
#  'PF',
#  'sqrt',
#  'log1p',
#  'log1pCP10k',
#  'log1pCPM',
#  'log1pPF',
#  'PFlog1pPF']

# %%
from brokenaxes import brokenaxes

# %%
fig = plt.figure(figsize=(10, 6))


bax = brokenaxes(
    xlims=((1e-16, 1e-13), (1e-3, 2e1)), hspace=0.05, xscale="log", yscale="log"
)

for method in labels:
    tmp = df.query(f"index == '{method}'")

    x = tmp["cov_cell"].values
    y = tmp["cov_gene"].values
    j = 0  # np.random.normal(0, 0.05, size=x.shape)
    bax.scatter(x + j, y, label=method)

# settings
bax.set(
    **{
        "xscale": "log",
        "yscale": "log",
    }
)

bax.set_xlabel("Coefficient of variation on tranform cell depth")
bax.set_ylabel("Coefficient of variation on tranform gene variances")

bax.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
fig.show()

# %%
# outliers are the result of cells with all zero entries
msp.query("index == 'PF'").query("cov_cell > 1e-10").ds
# Out:
# 1    GSM3576430
# 1    GSM3711764
# 1    GSM3576399
# 1    GSM3576403
# 1    GSM3576409
# 1    GSM3576412
# 1    GSM3576413
# Name: ds, dtype: object

# %%
nan.shape
# Out:
# (15,)

# %% [markdown]
# # Full to sparse

# %%
common = np.intersect1d(np.unique(mall["ds"]), np.unique(msp["ds"]))

# %%
fig, ax = plt.subplots(figsize=(10, 10))

method = "raw"

metrics = (
    msp.query(f"index == '{method}'")
    .set_index("ds")
    .loc[common]
    .sort_values("cov_gene")
)
x = metrics["cov_gene"]

metrics = mall.query(f"index == '{method}'").set_index("ds").loc[metrics.index.values]
y = metrics["cov_gene"]

color_method = "density"
c = -np.log(metrics[color_method])

im = ax.scatter(x, y, c=c, cmap="bone")

for xx, yy, d in list(zip(x, y, metrics.index.values))[-8:]:
    ax.annotate(d, (xx, yy))

cax = setup_colorbar(ax)
fig.colorbar(im, cax=cax, label=color_method)

ax.set(
    **{
        "title": method,
        "xlabel": "Coefficient of variation on tranform all gene variances",
        "ylabel": "Coefficient of variation on tranform subset gene variances",
        "xscale": "log",
        "yscale": "log",
    }
)
yex(ax)
fig.show()

# %%
# fig, ax = plt.subplots(figsize=(7,7))

# tmp = df.query("index == 'log1p'")

# # x = (tmp["max_cell"] - tmp["min_cell"]).values
# x = tmp["cov_cell"].values
# y = tmp["cov_gene"].values

# ax.scatter(x,y, edgecolor="k", facecolor="white")

# # linear regression
# lrx = np.log(x.reshape(-1,1))
# lry = np.log(y)

# reg = LinearRegression().fit(lrx, lry)
# r2 = reg.score(lrx, lry)

# xx = np.array([min(x), max(x)])

# #ax.plot(xx, reg.coef_*xx+ reg.intercept_, color="darkgray", linestyle="--", label=f"r$^2$: {r2:,.2f}", linewidth=3)
# ax.plot(xx, xx**(reg.coef_)*np.exp(reg.intercept_), color="darkgray", linestyle="--", label=f"r$^2$: {r2:,.2f}", linewidth=3)

# # settings
# ax.set(**{
#     "xscale": "log",
#     "yscale": "log",
#     "xlabel": "Coefficient of variation on raw cell depths",
#     "ylabel": "Coefficient of variation on tranform gene variances"
# })
# ax.legend()
# yex(ax)
# fig.show()

# %%
m = (
    mmread("/home/sina/projects/synchromesh/data/pbmc3k/sparse/raw.mtx.gz")
    .tocsr()
    .toarray()
)

# %%
m.shape
# Out:
# (2638, 13714)

# %%
m.sum(1)
# Out:
# array([327, 594, 469, ..., 267, 157, 286])

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(np.mean(np.exp(m) - 1, 0), np.var(np.exp(m) - 1, 0))
ax.set(**{"xscale": "log", "yscale": "log"})

yex(ax)
fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.scatter(np.mean(np.exp(m) - 1, 0), np.var(np.exp(m) - 1, 0))
ax.set(**{"xscale": "log", "yscale": "log"})

yex(ax)
fig.show()

# %% [markdown]
# m.sum(0).mean(), m.sum(1).mean()

# %%
m.sum(1)
# Out:
# array([323, 586, 465, ..., 261, 157, 283])

# %%
m.sum(0)
# Out:
# array([  54,   39,   26, ..., 5162, 5215, 5416])

# %%
x = df.query("index == 'raw'")["overdispersion"]

# %%
plt.hist(x)
# Out:
# (array([499.,  10.,   5.,   2.,   0.,   2.,   0.,   0.,   1.,   1.]),
#  array([ -1.        ,  25.91620858,  52.83241716,  79.74862574,
#         106.66483431, 133.58104289, 160.49725147, 187.41346005,
#         214.32966863, 241.24587721, 268.16208578]),
#  <BarContainer object of 10 artists>)

# %%
x.mean()
# Out:
# 6.321052953802078

# %%
x.min()
# Out:
# -1.0

# %%
x.median()
# Out:
# 1.6667367360032581

# %%
df.query("ds == 'angelidis_2019'")
# Out:
#         index    cov_gene      cov_cell  r2_depth  r_mono              ds  \
# 0         raw  113.862800  9.907292e-01  1.000000     0.0  angelidis_2019
# 1          PF   83.960367  7.683227e-15  0.000000     0.0  angelidis_2019
# 2       log1p    3.968802  7.279637e-01  0.796948     0.0  angelidis_2019
# 3     log1pPF    3.551760  2.164951e-01  0.057388     0.0  angelidis_2019
# 4   PFlog1pPF    4.601145  5.899306e-15  0.000000     0.0  angelidis_2019
# 5    log1pCPM    2.012474  5.235323e-01  0.672496     0.0  angelidis_2019
# 6  log1pCP10k    2.277969  3.633608e-01  0.435490     0.0  angelidis_2019
# 7        sqrt   14.397881  7.169946e-01  0.812185     0.0  angelidis_2019
#
#    ncells  ngenes   density  total_count  avg_per_cell  avg_per_gene  \
# 0   14813   21969  0.020306     12132443    819.040235    552.252856
# 1   14813   21969  0.020306     12132443    819.040235    552.252856
# 2   14813   21969  0.020306     12132443    819.040235    552.252856
# ...

# %%
np.percentile(x, [10, 25, 75, 90])
# Out:
# array([ 0.3166102 ,  0.68030478,  4.18054038, 11.5443303 ])

# %%
np.random.seed(19680801)

pts = np.random.rand(30) * 0.2
# Now let's make two outlier points which are far away from everything.
pts[[3, 14]] += 0.8

# If we were to simply plot pts, we'd lose most of the interesting
# details due to the outliers. So let's 'break' or 'cut-out' the y-axis
# into two portions - use the top (ax1) for the outliers, and the bottom
# (ax2) for the details of the majority of our data
fig, (ax1, ax2) = plt.subplots(2, 1, sharey=True)
fig.subplots_adjust(wspace=0.05)  # adjust space between axes

# plot the same data on both axes
ax1.plot(pts)
ax2.plot(pts)

# zoom-in / limit the view to different portions of the data
ax1.set_ylim(0.78, 1.0)  # outliers only
ax2.set_ylim(0, 0.22)  # most of the data

# hide the spines between ax and ax2
ax1.spines.bottom.set_visible(False)
ax2.spines.top.set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

# Now, let's turn towards the cut-out slanted lines.
# We create line objects in axes coordinates, in which (0,0), (0,1),
# (1,0), and (1,1) are the four corners of the axes.
# The slanted lines themselves are markers at those locations, such that the
# lines keep their angle and position, independent of the axes size or scale
# Finally, we need to disable clipping.

d = 0.5  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(
    marker=[(-1, -d), (1, d)],
    markersize=12,
    linestyle="none",
    color="k",
    mec="k",
    mew=1,
    clip_on=False,
)
ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)


plt.show()

# %% [markdown]
# --------------
